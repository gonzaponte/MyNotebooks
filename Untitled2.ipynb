# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
import scipy.optimize as scop

# %matplotlib inline

# %%
x = np.array([np.random.uniform(0., 1.) if np.random.uniform(0., 1.) < 0.3 else np.random.exponential(.182) if np.random.uniform(0., 1.) < 0.2 else np.random.normal(0.5, 0.2) for i in xrange(int(1e5))])

# %%
h = plt.hist(x, 100, range=(0,1))
